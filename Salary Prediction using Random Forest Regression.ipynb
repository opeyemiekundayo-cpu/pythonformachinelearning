# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

os.chdir('C:\\Users\\HP\\Desktop\\ML Course Content\\Part 2 - Regression\\Section 9 - Random Forest Regression') # to change file working directory

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values # to convert all columns but dependent column to matrix to represent independent variables
y = dataset.iloc[:, 2].values

# %%
#fitting the Random Forest regression model
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
# Visualizing the Random Forest regression results for higher resolution
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Real or Bluff (Random Forest Regression model)')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %%
y_pred= regressor.predict(np.array(6.5).reshape(1,-1))

# %%
y_pred
# Out:
# array([167000.])

# %%
#fitting the Random Forest regression model for increased number of trees
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
# Visualizing the Random Forest regression results for higher resolution
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Real or Bluff (Random Forest Regression model)')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %%
y_pred= regressor.predict(np.array(6.5).reshape(1,-1))

# %%
y_pred
# Out:
# array([158300.])

# %%
#fitting the Random Forest regression model for increased number of trees
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 300, random_state = 0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=0)

# %%
# Visualizing the Random Forest regression results for higher resolution
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Real or Bluff (Random Forest Regression model)')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %%
y_pred= regressor.predict(np.array(6.5).reshape(1,-1))

# %%
y_pred
# Out:
# array([160333.33333333])
